# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\Anchal paswan\Desktop\AI_ML\Python\Daily\people.csv")
data
# Out:
#     Age  Gender   Hometown  Height  Qualification Smoker
# 0    45    Male     Mumbai     167       Graduate    Yes
# 1    23  Female     Mumbai     170       Graduate     No
# 2    27    Male     Mumbai     175  Post-graduate     No
# 3    34    Male      Delhi     155       Graduate     No
# 4    43  Female     Mumbai     157  Post-graduate    Yes
# 5    34    Male      Delhi     167        Diploma    Yes
# 6    44  Female     Mumbai     165       Graduate    Yes
# 7    56  Female      Delhi     170        Diploma    Yes
# 8    34    Male      Delhi     175  Post-graduate     No
# 9    49  Female  Bangalore     162  Post-graduate    Yes
# 10   35    Male  Bangalore     160       Graduate     No
# 11   28  Female     Mumbai     165        Diploma     No
# 12   54    Male      Delhi     170        Diploma    Yes
# 13   59  Female     Mumbai     175       Graduate     No
# 14   54    Male  Bangalore     175        Diploma    Yes
# ...

# %%
pd.crosstab(data.Gender , data.Smoker , values =data.Age , aggfunc = "mean",rownames = ["gen"] , colnames = ['Smokerss'])
# Out:
# Smokerss         No        Yes
# gen
# Female    38.333333  48.000000
# Male      34.200000  49.333333

# %%
duplicates = data[data.duplicated(keep = False)]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Hometown, Height, Qualification]
# Index: []

# %%
data.drop(index=[2,4] , columns = ["Smoker"] , )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 data.drop(index=[2,4,] , columns = ["Smoker"] , inplace = True)
#
# File c:\Users\Anchal paswan\Desktop\Data Analysis Using Python\.venv\Lib\site-packages\pandas\core\frame.py:6300, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    6296                 weight  250.0   150.0
#    6297         falcon  speed   320.0   250.0
#    6298                 weight  1.0     0.8
#    6299         """
# -> 6300         return super().drop(
#    6301             labels=labels,
#    6302             axis=axis,
#    6303             index=index,
#
# File c:\Users\Anchal paswan\Desktop\Data Analysis Using Python\.venv\Lib\site-packages\pandas\core\generic.py:4644, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4640         obj = self
#    4641
# ...

# %% [markdown]
# MAP AND REPLACE

# %%
words = ["anchal" , "shubh" , "anuj"]
list(map(lambda x: x.capitalize() , words))
# Out:
# ['Anchal', 'Shubh', 'Anuj']

# %%
names = [x.capitalize() for x in words]
print(names)
# Out:
# ['Anchal', 'Shubh', 'Anuj']

# %%
# create a dictionary
import pandas as pd
data = { 'Name':['Anne','Bobby','James','Lewis','Ross','Cathrine',
            'Anne','Bobby','Jack','Alisa','Alex','Cathrine'],
    'Company':['Apple','Walmart','Walmart','Intel','Apple','Walmart','Apple',
               'Cognizant','Apple','Apple','Cognizant','Walmart'],
    'Salary':[8500, 6300, 5500, 7400, 3100, 7700, 8500, 6300, 4200, 6200, 8900, 7700]}

# create a DataFrame
df_employee = pd.DataFrame(data, columns=['Name','Company','Salary'])
df_employee

# %%
import pandas as pd

data = {
    "Country": [
        "India",
        "China",
        "United States",
        "Indonesia",
        "Pakistan",
        "Brazil"
    ],
    "Population": [
        1438000000,
        1410000000,
        340000000,
        281000000,
        252000000,
        212000000
    ]
}

df = pd.DataFrame(data)

print(df)
# Out:
#          Country  Population
# 0          India  1438000000
# 1          China  1410000000
# 2  United States   340000000
# 3      Indonesia   281000000
# 4       Pakistan   252000000
# 5         Brazil   212000000

# %%
capitals = {
    "India" : "Delhi",
    "China" : "Bejing",
    "United States" : "NWC",
    "Indonesia" : "Jakarta",
    "Pakistan": "Lahore ", 
    "Brazil":"Brasillia"
}

# %%
df["capital"] = df.Country.map(capitals)
df
# Out:
#          Country  Population    capital
# 0          India  1438000000      Delhi
# 1          China  1410000000     Bejing
# 2  United States   340000000        NWC
# 3      Indonesia   281000000    Jakarta
# 4       Pakistan   252000000    Lahore
# 5         Brazil   212000000  Brasillia
